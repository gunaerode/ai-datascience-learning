# %%
import pickle
loaded_model=pickle.load(open("mlr_practice_model.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]]) # independent values only / input
result
# Out:
# C:\Users\gunac\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[43994.79745873]])
